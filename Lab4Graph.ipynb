# %%
import math
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('pm25_sensor_data (1).csv',skiprows=1)

# %%
display(data)
# Out:
#               Timestamp  PM1.0 (std)  PM2.5 (std)  PM10 (std)  PM1.0 (env)  \
# 0   2025-02-14 16:02:16            0            0           0            0
# 1   2025-02-14 16:02:17            0            0           0            0
# 2   2025-02-14 16:02:18            0            0           0            0
# 3   2025-02-14 16:02:19            0            0           0            0
# 4   2025-02-14 16:02:20            0            0           0            0
# 5   2025-02-14 16:02:21            0            0           0            0
# 6   2025-02-14 16:02:22            0            0           0            0
# 7   2025-02-14 16:02:23            0            0           0            0
# 8   2025-02-14 16:02:24            0            0           0            0
# 9   2025-02-14 16:02:25            0            0           0            0
# 10  2025-02-14 16:02:26            0            0           0            0
# ...

# %%
plt.hist(data["PM2.5 (std)"], bins=[0,1,2])
plt.xti
plt.ylabel('Frequency')   
plt.xlabel('PM2.5 (Standard)')
plt.title("Frequency Distribution PM2.5")                                  
plt.show()
